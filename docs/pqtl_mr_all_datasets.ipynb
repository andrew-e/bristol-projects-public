# %% [markdown]
# # Results from Running MR on pQTL data
#
# Below are results from
# * pQTL -> published AIS
# * pQTL -> Subsequent MACE (original, slopehunter adjusted)
# * pQTL -> Subsequent AIS (original, slopehunter adjusted)

# %%
merge_original_pqtl_pval <- function(mr_results, exposures) {
    colnames(exposures) <- c("exposure","pqtl_pval")
    return(merge(mr_results, exposures, by="exposure"))
}

# %%
exposures = c("ADAMTS13", "CD2AP", "CGREF1", "COMT", "CST6", "EGFR", "FGF5", "FURIN", "GRK5", "KLK1", "MMP12", "PFKFB2", "SCARA5")
sub_exposures = c("CCL27", "IL19", "TNFRSF14")

aric <- data.table::fread("scratch/data/pqtl/aric_interesting_exposures.tsv", select=c("exposure", "P"))
decode <- data.table::fread("scratch/data/pqtl/decode_interesting_exposures.tsv", select=c("exposure", "P"))
phenoscanner <- data.table::fread("scratch/data/pqtl/phenoscanner_interesting_exposures.tsv", select=c("exposure", "P"))

mr_publised_ukb <- data.table::fread("scratch/results/mr/mr_published_ais_cis.tsv")
mr_publised_aric <- merge_original_pqtl_pval(data.table::fread("scratch/results/mr/mr_published_ais_aric.tsv"), aric)
mr_published_decode <- merge_original_pqtl_pval(data.table::fread("scratch/results/mr/mr_published_ais_decode.tsv"), decode)
mr_published_phenoscanner <- merge_original_pqtl_pval(data.table::fread("scratch/results/mr/mr_published_ais_phenoscanner.tsv"), phenoscanner)

mr_sub_ais_ukb <- data.table::fread("scratch/results/mr/mr_subsequent_ais_slopehunter_cis.tsv")
mr_sub_ais_aric <- merge_original_pqtl_pval(data.table::fread("scratch/results/mr/mr_subsequent_ais_sh_aric.tsv"), aric)
mr_sub_ais_decode <- merge_original_pqtl_pval(data.table::fread("scratch/results/mr/mr_subsequent_ais_sh_decode.tsv"), decode)
mr_sub_ais_phenoscanner <- merge_original_pqtl_pval(data.table::fread("scratch/results/mr/mr_subsequent_ais_sh_phenoscanner.tsv"), phenoscanner)

mr_sub_mace_ukb <- data.table::fread("scratch/results/mr/mr_subsequent_mace_slopehunter_cis.tsv")
mr_sub_mace_aric <- merge_original_pqtl_pval(data.table::fread("scratch/results/mr/mr_subsequent_mace_sh_aric.tsv"), aric)
mr_sub_mace_decode <- merge_original_pqtl_pval(data.table::fread("scratch/results/mr/mr_subsequent_mace_sh_decode.tsv"), decode)
mr_sub_mace_phenoscanner <- merge_original_pqtl_pval(data.table::fread("scratch/results/mr/mr_subsequent_mace_sh_phenoscanner.tsv"), phenoscanner)

published <- rbind(mr_publised_ukb, mr_publised_aric, mr_published_decode, mr_published_phenoscanner, fill=TRUE)
sub_ais <- rbind(mr_sub_ais_ukb, mr_sub_ais_aric, mr_sub_ais_decode, mr_sub_ais_phenoscanner, fill=TRUE)
sub_mace <- rbind(mr_sub_mace_ukb, mr_sub_mace_aric, mr_sub_mace_decode, mr_sub_mace_phenoscanner, fill=TRUE)

IRdisplay::display_markdown("### Subsequent AIS pQTL comparison")

sub_ais <- subset(sub_ais, (exposure %in% sub_exposures) == TRUE)
sub_ais[with(sub_ais, order(exposure, outcome)), ]

IRdisplay::display_markdown("### Subsequent MACE pQTL comparison")
sub_mace <- subset(sub_mace, (exposure %in% sub_exposures) == TRUE)
sub_mace[with(sub_mace, order(exposure, outcome)), ]

IRdisplay::display_markdown("### Incident AIS pQTL comparison")
published <- subset(published, (exposure %in% exposures) == TRUE)
published[with(published, order(exposure, outcome)), ]
# Out:
# ### Subsequent AIS pQTL comparison
#    id.exposure id.outcome outcome                        exposure method
# 1  rsPaBv      snw3Gr     subsequent_ais_aric            CCL27    Wald ratio
# 2  R6Ptnt      thmMyl     subsequent_ais_decode          CCL27    Wald ratio
# 3  EKehjv      fZ5nNw     subsequent_ais_phenoscanner    CCL27    Wald ratio
# 4  Qn8W57      kuKFok     subsequent_ais_slopehunter_cis CCL27    Wald ratio
# 5  puYTLi      snw3Gr     subsequent_ais_aric            IL19     Wald ratio
# 6  UE4S3N      thmMyl     subsequent_ais_decode          IL19     Wald ratio
# 7  3VY4em      fZ5nNw     subsequent_ais_phenoscanner    IL19     Wald ratio
# 8  Ps4kKE      kuKFok     subsequent_ais_slopehunter_cis IL19     Wald ratio
# 9  Ovb15k      snw3Gr     subsequent_ais_aric            TNFRSF14 Wald ratio
# 10 ZHap0S      thmMyl     subsequent_ais_decode          TNFRSF14 Wald ratio
# 11 CAfoOe      fZ5nNw     subsequent_ais_phenoscanner    TNFRSF14 Wald ratio
# 12 4YPe28      kuKFok     subsequent_ais_slopehunter_cis TNFRSF14 Wald ratio
#    nsnp b            se         pval         pval_adjusted pqtl_pval
# 1  1     -0.60865624 0.17575180 5.338750e-04 0.002135500   1.804020e-04
# 2  1     -0.85677083 0.24739583 5.338750e-04 0.001601625   2.837000e-08
# 3  1     -0.40220049 0.11613692 5.338750e-04 0.001601625   7.200000e-05
# 4  1     -0.18954318 0.05780611 1.041951e-03 0.540251421             NA
# 5  1    -31.31315088 8.00583651 9.180434e-05 0.001101652   9.300000e-01
# 6  1     21.08695652 5.39130435 9.180434e-05 0.000826239   8.238920e-01
# 7  1      6.38157895 1.63157895 9.180434e-05 0.000826239   7.943282e-01
# 8  1     -0.09164577 0.03489916 8.639069e-03 0.691912817             NA
# 9  1      1.59078466 0.44835123 3.880549e-04 0.002135500   1.628210e-01
# 10 1    -10.85294118 3.05882353 3.880549e-04 0.001601625   6.660360e-01
# 11 1      0.60097720 0.16938111 3.880549e-04 0.001601625   1.340000e-02
# 12 1      0.35195930 0.08973220 8.769673e-05 0.090941511             NA
# ### Subsequent MACE pQTL comparison
#    id.exposure id.outcome outcome                         exposure method
# 1  rsPaBv      vAgRVR     subsequent_mace_aric            CCL27    Wald ratio
# 2  R6Ptnt      XeFfIA     subsequent_mace_decode          CCL27    Wald ratio
# 3  EKehjv      8DtDUt     subsequent_mace_phenoscanner    CCL27    Wald ratio
# 4  Qn8W57      Y5SY88     subsequent_mace_slopehunter_cis CCL27    Wald ratio
# 5  puYTLi      vAgRVR     subsequent_mace_aric            IL19     Wald ratio
# 6  UE4S3N      XeFfIA     subsequent_mace_decode          IL19     Wald ratio
# 7  3VY4em      8DtDUt     subsequent_mace_phenoscanner    IL19     Wald ratio
# 8  Ps4kKE      Y5SY88     subsequent_mace_slopehunter_cis IL19     Wald ratio
# 9  Ovb15k      vAgRVR     subsequent_mace_aric            TNFRSF14 Wald ratio
# 10 ZHap0S      XeFfIA     subsequent_mace_decode          TNFRSF14 Wald ratio
# 11 CAfoOe      8DtDUt     subsequent_mace_phenoscanner    TNFRSF14 Wald ratio
# 12 4YPe28      Y5SY88     subsequent_mace_slopehunter_cis TNFRSF14 Wald ratio
#    nsnp b            se         pval         pval_adjusted pqtl_pval
# 1  1     -0.56240576 0.18037685 1.821145e-03 0.007284580   1.804020e-04
# 2  1     -0.79166667 0.25390625 1.821145e-03 0.005463435   2.837000e-08
# 3  1     -0.37163814 0.11919315 1.821145e-03 0.005463435   7.200000e-05
# 4  1     -0.26377839 0.05811035 5.645012e-06 0.005882102             NA
# 5  1    -30.86120849 8.19952611 1.673645e-04 0.001004187   9.300000e-01
# 6  1     20.78260870 5.52173913 1.673645e-04 0.000753140   8.238920e-01
# 7  1      6.28947368 1.67105263 1.673645e-04 0.000753140   7.943282e-01
# 8  1     -0.06554233 0.03518289 6.247588e-02 0.989644370             NA
# 9  1      1.73304995 0.45697337 1.491666e-04 0.001004187   1.628210e-01
# 10 1    -11.82352941 3.11764706 1.491666e-04 0.000753140   6.660360e-01
# 11 1      0.65472313 0.17263844 1.491666e-04 0.000753140   1.340000e-02
# 12 1      0.24306100 0.09147457 7.880604e-03 0.826006445             NA
# ### Incident AIS pQTL comparison
#    id.exposure id.outcome outcome                    exposure method     nsnp
# 1  A7vwyH      lBNVIR     published_ais_aric         CGREF1   Wald ratio 1
# 2  rQaVOv      INUKiX     published_ais_cis          CGREF1   Wald ratio 1
# 3  SbgGkQ      LdEOtn     published_ais_decode       CGREF1   Wald ratio 1
# 4  NZxVAy      qayDJE     published_ais_phenoscanner CGREF1   Wald ratio 1
# 5  fuQcZX      lBNVIR     published_ais_aric         COMT     Wald ratio 1
# 6  NSLrUT      LdEOtn     published_ais_decode       COMT     Wald ratio 1
# 7  qhrLUV      lBNVIR     published_ais_aric         CST6     Wald ratio 1
# 8  W7UH7U      INUKiX     published_ais_cis          CST6     Wald ratio 1
# 9  NOLeBh      LdEOtn     published_ais_decode       CST6     Wald ratio 1
# 10 0EsJqk      qayDJE     published_ais_phenoscanner CST6     Wald ratio 1
# 11 l6cwY4      lBNVIR     published_ais_aric         FGF5     Wald ratio 1
# 12 s7WS3b      INUKiX     published_ais_cis          FGF5     Wald ratio 1
# 13 MbUH8q      LdEOtn     published_ais_decode       FGF5     Wald ratio 1
# 14 QVzgZm      qayDJE     published_ais_phenoscanner FGF5     Wald ratio 1
# 15 wa0EFl      lBNVIR     published_ais_aric         FURIN    Wald ratio 1
# 16 TMwec8      INUKiX     published_ais_cis          FURIN    Wald ratio 1
# 17 5sXatJ      LdEOtn     published_ais_decode       FURIN    Wald ratio 1
# 18 kmcJKO      qayDJE     published_ais_phenoscanner FURIN    Wald ratio 1
# 19 5xe0zC      INUKiX     published_ais_cis          GRK5     Wald ratio 1
# 20 oa1kjA      lBNVIR     published_ais_aric         MMP12    Wald ratio 1
# 21 vK39DA      INUKiX     published_ais_cis          MMP12    Wald ratio 1
# 22 x5rElV      LdEOtn     published_ais_decode       MMP12    Wald ratio 1
# 23 lf8xw8      qayDJE     published_ais_phenoscanner MMP12    Wald ratio 1
# 24 bRkvUr      lBNVIR     published_ais_aric         SCARA5   Wald ratio 1
# 25 iAIhMT      INUKiX     published_ais_cis          SCARA5   Wald ratio 1
# 26 RFD9qx      qayDJE     published_ais_phenoscanner SCARA5   Wald ratio 1
#    b           se          pval         pval_adjusted pqtl_pval
# 1  -4.30109909 1.070659859 5.888340e-05 1.177668e-04   7.531460e-01
# 2  -0.04172412 0.010386261 5.888340e-05 7.113115e-03             NA
# 3   2.50537634 0.623655914 5.888340e-05 1.059901e-04   2.712290e-01
# 4   0.96680498 0.240663900 5.888340e-05 1.324877e-04   3.467369e-01
# 5  -0.47100494 0.116809224 5.524348e-05 1.177668e-04   1.354570e-03
# 6  -0.30450670 0.075517661 5.524348e-05 1.059901e-04   3.162000e-23
# 7   0.07345203 0.017673889 3.239198e-05 1.079733e-04   2.453230e-31
# 8   0.07622554 0.018341245 3.239198e-05 4.891189e-03             NA
# 9   0.08457804 0.020351008 3.239198e-05 9.717595e-05   7.143000e-78
# 10  0.07730375 0.018600683 3.239198e-05 9.717595e-05   8.912509e-15
# 11  5.31609067 0.726659876 2.558726e-13 2.558726e-12   6.649470e-01
# 12  0.06129667 0.008378681 2.558726e-13 1.545470e-10             NA
# 13 23.16666667 3.166666667 2.558726e-13 2.302853e-12   8.311150e-01
# 14 -1.68145161 0.229838710 2.558726e-13 2.302853e-12   3.548134e-01
# 15 -0.98008995 0.260830389 1.715674e-04 2.859457e-04   1.500400e-01
# 16  0.12656548 0.033682749 1.715674e-04 1.727112e-02             NA
# 17  9.92000000 2.640000000 1.715674e-04 2.573512e-04   7.741900e-01
# 18  1.16981132 0.311320755 1.715674e-04 3.088214e-04   4.168694e-01
# 19 -0.16458009 0.025777604 1.718288e-10 5.189229e-08             NA
# 20 -0.05793495 0.011640509 6.457349e-07 3.228674e-06  7.128450e-215
# 21 -0.05813384 0.011680471 6.457349e-07 1.300080e-04             NA
# 22 -0.06083169 0.012222534 6.457349e-07 2.905807e-06   0.000000e+00
# 23 -0.05556268 0.011163865 6.457349e-07 2.905807e-06  1.096478e-110
# 24 -0.08677679 0.024060838 3.102863e-04 4.432661e-04   9.928290e-41
# 25 -0.06567047 0.018208629 3.102863e-04 2.677327e-02             NA
# 26 -0.08699091 0.024120206 3.102863e-04 4.654294e-04   6.025596e-20
