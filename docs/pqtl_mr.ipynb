# %% [markdown]
# # Results from Running MR on pQTL data
#
# Below are results from
# pQTL -> Subsequent MACE (original, slopehunter, and dudbridge adjusted)
# pQTL -> Subsequent AIS (original, slopehunter, and dudbridge adjusted)

# %%
mr_mace <- data.table::fread("scratch/results/mr/mr_subsequent_mace.tsv")
mr_mace_slopehunter <- data.table::fread("scratch/results/mr/mr_subsequent_mace_slopehunter.tsv")
mr_mace_dudbridge <- data.table::fread("scratch/results/mr/mr_subsequent_mace_dudbridge.tsv")

mr_ais <- data.table::fread("scratch/results/mr/mr_subsequent_ais.tsv")
mr_ais_slopehunter <- data.table::fread("scratch/results/mr/mr_subsequent_ais_slopehunter.tsv")
mr_ais_dudbridge <- data.table::fread("scratch/results/mr/mr_subsequent_ais_dudbridge.tsv")

print("MR MACE Ordered by adjusted p palue")
head(mr_mace[with(mr_mace, order(pval_adjusted)), ])
print("MR MACE SlopeHunter Corrected Ordered by adjusted p palue")
head(mr_mace_slopehunter[with(mr_mace_slopehunter, order(pval_adjusted)), ])
print("MR MACE Dudbridge Corrected Ordered by adjusted p palue")
head(mr_mace_dudbridge[with(mr_mace_dudbridge, order(pval_adjusted)), ])

print("MR AIS Ordered by adjusted p palue")
head(mr_ais[with(mr_ais, order(pval_adjusted)), ])
print("MR AIS SlopeHunter Corrected Ordered by adjusted p palue")
head(mr_ais_slopehunter[with(mr_ais_slopehunter, order(pval_adjusted)), ])
print("MR AIS Dudbridge Corrected Ordered by adjusted p palue")
head(mr_ais_dudbridge[with(mr_ais_dudbridge, order(pval_adjusted)), ])
# Out:
# [1] "MR MACE Ordered by adjusted p palue"
#   id.exposure id.outcome outcome                      exposure
# 1 kiNVNe      e5K55p     subsequent_mace_non_adjusted IL19
# 2 xP0Mo3      e5K55p     subsequent_mace_non_adjusted KRT5
# 3 1KYXy0      e5K55p     subsequent_mace_non_adjusted CD164
# 4 2AaKpG      e5K55p     subsequent_mace_non_adjusted HSPB6
# 5 6r3Omf      e5K55p     subsequent_mace_non_adjusted AMY2B
# 6 gw2kzS      e5K55p     subsequent_mace_non_adjusted IL34
#   method                    nsnp b           se         pval
# 1 Inverse variance weighted  5    0.09559821 0.02250109 2.151074e-05
# 2 Inverse variance weighted  4   -0.23341089 0.06046804 1.133544e-04
# 3 Inverse variance weighted 10   -0.14704592 0.04192116 4.520359e-04
# 4 Inverse variance weighted  7   -0.23305281 0.07506760 1.905543e-03
# 5 Inverse variance weighted  9    0.07423689 0.02426929 2.221647e-03
# 6 Wald ratio                 1    0.04846180 0.01584328 2.222080e-03
#   pval_adjusted
# 1 0.02929762
# 2 0.07719435
# 3 0.20522429
# 4 0.50441216
# 5 0.50441216
# 6 0.50441216
# [1] "MR MACE SlopeHunter Corrected Ordered by adjusted p palue"
#   id.exposure id.outcome outcome                     exposure
# 1 06WyYd      pYSm87     subsequent_mace_slopehunter THOP1
# 2 07e9PF      pYSm87     subsequent_mace_slopehunter SPINK6
# 3 08GAMn      pYSm87     subsequent_mace_slopehunter PODXL2
# 4 0B9iOS      pYSm87     subsequent_mace_slopehunter LTA
# 5 0cZuVR      pYSm87     subsequent_mace_slopehunter ICOSLG
# 6 0HjIaQ      pYSm87     subsequent_mace_slopehunter SDC4
#   method                    nsnp b            se         pval
# 1 Wald ratio                 1    0.010250180 0.04289890 0.8111536
# 2 Wald ratio                 1    0.041820590 0.02927441 0.1531275
# 3 Inverse variance weighted 11   -0.001417963 0.04913781 0.9769787
# 4 Inverse variance weighted  9    0.004101670 0.01448645 0.7770708
# 5 Inverse variance weighted  2    0.037703762 0.02782000 0.1753297
# 6 Inverse variance weighted 18   -0.010239589 0.03888999 0.7923222
#   pval_adjusted
# 1 0.999226
# 2 0.999226
# 3 0.999226
# 4 0.999226
# 5 0.999226
# 6 0.999226
# [1] "MR MACE Dudbridge Corrected Ordered by adjusted p palue"
#   id.exposure id.outcome outcome                   exposure
# 1 aTsOce      ha1afw     subsequent_mace_dudbridge PTGDS
# 2 gI7KnP      ha1afw     subsequent_mace_dudbridge LDLR
# 3 gKVpO0      ha1afw     subsequent_mace_dudbridge LYPD8
# 4 06WyYd      ha1afw     subsequent_mace_dudbridge THOP1
# 5 07e9PF      ha1afw     subsequent_mace_dudbridge SPINK6
# 6 08GAMn      ha1afw     subsequent_mace_dudbridge PODXL2
#   method                    nsnp b            se          pval
# 1 Inverse variance weighted  3   -0.164722326 0.050115964 0.001013243
# 2 Inverse variance weighted 12   -0.096163343 0.030719825 0.001746071
# 3 Inverse variance weighted 10    0.026709881 0.008278523 0.001253552
# 4 Wald ratio                 1   -0.004555636 0.041759994 0.913130385
# 5 Wald ratio                 1    0.042099394 0.028716805 0.142642997
# 6 Inverse variance weighted 11    0.001014474 0.034089885 0.976259410
#   pval_adjusted
# 1 0.7828216
# 2 0.7828216
# 3 0.7828216
# 4 0.9996620
# 5 0.9996620
# 6 0.9996620
# [1] "MR AIS Ordered by adjusted p palue"
#   id.exposure id.outcome outcome                     exposure
# 1 bhaC9U      A9OGYY     subsequent_ais_non_adjusted GOLM2
# 2 CTr32W      A9OGYY     subsequent_ais_non_adjusted CD164
# 3 eWg6bw      A9OGYY     subsequent_ais_non_adjusted IL19
# 4 8a0dZM      A9OGYY     subsequent_ais_non_adjusted NFATC1
# 5 AVLm3F      A9OGYY     subsequent_ais_non_adjusted TSHB
# 6 BHJbir      A9OGYY     subsequent_ais_non_adjusted REG1B
#   method                    nsnp b           se         pval
# 1 Inverse variance weighted  9   -0.09150730 0.02699385 0.0006990994
# 2 Inverse variance weighted 10   -0.14755911 0.04227295 0.0004818876
# 3 Inverse variance weighted  5    0.08204006 0.02532138 0.0011954963
# 4 Wald ratio                 1    0.25219684 0.09490334 0.0078744218
# 5 Inverse variance weighted 19    0.08714700 0.03259466 0.0075028725
# 6 Inverse variance weighted  7   -0.07302333 0.02504910 0.0035545155
#   pval_adjusted
# 1 0.4750380
# 2 0.4750380
# 3 0.5415598
# 4 0.9958199
# 5 0.9958199
# 6 0.9958199
# [1] "MR AIS SlopeHunter Corrected Ordered by adjusted p palue"
#   id.exposure id.outcome outcome                    exposure
# 1 eWg6bw      1n0548     subsequent_ais_slopehunter IL19
# 2 NTANZK      1n0548     subsequent_ais_slopehunter AGER
# 3 CTr32W      1n0548     subsequent_ais_slopehunter CD164
# 4 06fJdX      1n0548     subsequent_ais_slopehunter GRPEL1
# 5 08Epug      1n0548     subsequent_ais_slopehunter ENPP5
# 6 0AiIdF      1n0548     subsequent_ais_slopehunter ARSB
#   method                    nsnp b            se         pval
# 1 Inverse variance weighted  4    0.076313270 0.02085222 0.0002524918
# 2 Inverse variance weighted 17   -0.125532526 0.03549722 0.0004056129
# 3 Inverse variance weighted  9   -0.148289437 0.04462253 0.0008899210
# 4 Inverse variance weighted  3   -0.130637383 0.09238939 0.1573657460
# 5 Inverse variance weighted  7   -0.006054974 0.01390788 0.6632990547
# 6 Inverse variance weighted  7   -0.014715578 0.03256398 0.6513428623
#   pval_adjusted
# 1 0.2719635
# 2 0.2719635
# 3 0.3977947
# 4 0.9957890
# 5 0.9957890
# 6 0.9957890
# [1] "MR AIS Dudbridge Corrected Ordered by adjusted p palue"
#   id.exposure id.outcome outcome                  exposure
# 1 CTr32W      7xaRuy     subsequent_ais_dudbridge CD164
# 2 eWg6bw      7xaRuy     subsequent_ais_dudbridge IL19
# 3 NTANZK      7xaRuy     subsequent_ais_dudbridge AGER
# 4 06fJdX      7xaRuy     subsequent_ais_dudbridge GRPEL1
# 5 08Epug      7xaRuy     subsequent_ais_dudbridge ENPP5
# 6 0AiIdF      7xaRuy     subsequent_ais_dudbridge ARSB
#   method                    nsnp b            se         pval
# 1 Inverse variance weighted  9   -0.162096162 0.04395879 0.0002265059
# 2 Inverse variance weighted  4    0.074376141 0.02059391 0.0003043605
# 3 Inverse variance weighted 17   -0.110551537 0.03386579 0.0010969549
# 4 Inverse variance weighted  3   -0.111070670 0.09099303 0.2222184340
# 5 Inverse variance weighted  7   -0.006899815 0.01376755 0.6162550444
# 6 Inverse variance weighted  7   -0.015132591 0.03106259 0.6261418137
#   pval_adjusted
# 1 0.2040737
# 2 0.2040737
# 3 0.4903389
# 4 0.9985057
# 5 0.9985057
# 6 0.9985057

# %% [markdown]
# -------------
# ## Code that generated the above data
# -------------

# %%
library(TwoSampleMR)

ais_exp<- TwoSampleMR::read_exposure_data("scratch/data/pqtl/all_biobank_pqtl_instruments.tsv",
                            sep="\t",
                            snp_col="marker.exposure",
                            effect_allele_col="effect_allele.exposure",
                            other_allele_col="other_allele.exposure",
                            eaf_col="eaf.exposure",
                            beta_col="beta.exposure",
                            se_col="se.exposure",
                            pval_col="pval.exposure",
                            phenotype_col="exposure"
)
#ais_exp <- clump_data(ais_exp)

ais_outcome_data <- TwoSampleMR::read_outcome_data("scratch/results/meta_analysis/subsequent_ais_metal_metaanalysis.tbl",
                  sep = "\t",
                  snp_col = "MARKER",
                  beta_col = "BETA",
                  se_col = "SE",
                  effect_allele_col = "Allele1",
                  other_allele_col = "Allele2",
                  pval_col = "P",
                  eaf_col = "Freq1",
                  snps = ais_exp$SNP
)
ais_outcome_data$outcome <- "subsequent_ais_non_adjusted"

ais_outcome_data_slopehunter <- TwoSampleMR::read_outcome_data("scratch/results/subsequent_ais_metaanalysis_slopehunter1.txt",
                  sep=" ",
                  snp_col = "MARKER",
                  beta_col = "BETA",
                  se_col = "SE",
                  effect_allele_col = "EA",
                  other_allele_col = "NONEA",
                  pval_col = "P",
                  eaf_col = "EAF",
                  snps = ais_exp$SNP
)
ais_outcome_data_slopehunter$outcome <- "subsequent_ais_slopehunter"

ais_outcome_data_dudbridge <- TwoSampleMR::read_outcome_data("scratch/results/subsequent_ais_metaanalysis_dudbridge1.txt",
                  sep=" ",
                  snp_col = "MARKER",
                  beta_col = "BETA",
                  se_col = "SE",
                  effect_allele_col = "EA",
                  other_allele_col = "NONEA",
                  pval_col = "P",
                  eaf_col = "EAF",
                  snps = ais_exp$SNP
)
ais_outcome_data_dudbridge$outcome <- "subsequent_ais_dudbridge"

ais_harmonized <- TwoSampleMR::harmonise_data(ais_exp, ais_outcome_data)
ais_results <- mr(ais_harmonized, method_list=c("mr_wald_ratio", "mr_ivw"))
ais_results$pval_adjusted <- p.adjust(ais_results$pval, "fdr")


ais_slopehunter_harmonized <- TwoSampleMR::harmonise_data(ais_exp, ais_outcome_data_slopehunter)
ais_slopehunter_results <- mr(ais_slopehunter_harmonized, method_list=c("mr_wald_ratio", "mr_ivw"))
ais_slopehunter_results$pval_adjusted <- p.adjust(ais_slopehunter_results$pval, "fdr")

ais_dudbridge_harmonized <- TwoSampleMR::harmonise_data(ais_exp, ais_outcome_data_dudbridge)
ais_dudbridge_results <- mr(ais_dudbridge_harmonized, method_list=c("mr_wald_ratio", "mr_ivw"))
ais_dudbridge_results$pval_adjusted <- p.adjust(ais_dudbridge_results$pval, "fdr")

data.table::fwrite(ais_results, "scratch/results/mr/mr_subsequent_ais.tsv", sep="\t")
data.table::fwrite(ais_slopehunter_results, "scratch/results/mr/mr_subsequent_ais_slopehunter.tsv", sep="\t")
data.table::fwrite(ais_dudbridge_results, "scratch/results/mr/mr_subsequent_ais_dudbridge.tsv", sep="\t")

# %%
library(TwoSampleMR)

ais_exp<- TwoSampleMR::read_exposure_data("scratch/data/pqtl/all_biobank_pqtl_instruments.tsv",
                            sep="\t",
                            snp_col="marker.exposure",
                            effect_allele_col="effect_allele.exposure",
                            other_allele_col="other_allele.exposure",
                            eaf_col="eaf.exposure",
                            beta_col="beta.exposure",
                            se_col="se.exposure",
                            pval_col="pval.exposure",
                            phenotype_col="exposure"
)
#ais_exp <- clump_data(ais_exp)

mace_outcome_data <- TwoSampleMR::read_outcome_data("scratch/results/meta_analysis/subsequent_mace_metal_metaanalysis.tbl",
                  sep = "\t",
                  snp_col = "MARKER",
                  beta_col = "BETA",
                  se_col = "SE",
                  effect_allele_col = "Allele1",
                  other_allele_col = "Allele2",
                  pval_col = "P",
                  eaf_col = "Freq1",
                  snps = ais_exp$SNP
)
mace_outcome_data$outcome <- "subsequent_mace_non_adjusted"

mace_outcome_data_slopehunter <- TwoSampleMR::read_outcome_data("scratch/results/subsequent_mace_metaanalysis_slopehunter1.txt",
                  sep=" ",
                  snp_col = "MARKER",
                  beta_col = "BETA",
                  se_col = "SE",
                  effect_allele_col = "EA",
                  other_allele_col = "NONEA",
                  pval_col = "P",
                  eaf_col = "EAF",
                  snps = ais_exp$SNP
)
mace_outcome_data_slopehunter$outcome <- "subsequent_mace_slopehunter"

mace_outcome_data_dudbridge <- TwoSampleMR::read_outcome_data("scratch/results/subsequent_mace_metaanalysis_dudbridge1.txt",
                  sep=" ",
                  snp_col = "MARKER",
                  beta_col = "BETA",
                  se_col = "SE",
                  effect_allele_col = "EA",
                  other_allele_col = "NONEA",
                  pval_col = "P",
                  eaf_col = "EAF",
                  snps = ais_exp$SNP
)
mace_outcome_data_dudbridge$outcome <- "subsequent_mace_dudbridge"

mace_harmonized <- TwoSampleMR::harmonise_data(ais_exp, mace_outcome_data)
mace_results <- mr(mace_harmonized, method_list=c("mr_wald_ratio", "mr_ivw"))
mace_results$pval_adjusted <- p.adjust(mace_results$pval, "fdr")


mace_slopehunter_harmonized <- TwoSampleMR::harmonise_data(ais_exp, mace_outcome_data_slopehunter)
mace_slopehunter_results <- mr(mace_slopehunter_harmonized, method_list=c("mr_wald_ratio", "mr_ivw"))
mace_slopehunter_results$pval_adjusted <- p.adjust(mace_slopehunter_results$pval, "fdr")

mace_dudbridge_harmonized <- TwoSampleMR::harmonise_data(ais_exp, mace_outcome_data_dudbridge)
mace_dudbridge_results <- mr(mace_dudbridge_harmonized, method_list=c("mr_wald_ratio", "mr_ivw"))
mace_dudbridge_results$pval_adjusted <- p.adjust(mace_dudbridge_results$pval, "fdr")

data.table::fwrite(mace_results, "scratch/results/mr/mr_subsequent_mace.tsv", sep="\t")
data.table::fwrite(mace_slopehunter_results, "scratch/results/mr/mr_subsequent_mace_slopehunter.tsv", sep="\t")
data.table::fwrite(mace_dudbridge_results, "scratch/results/mr/mr_subsequent_mace_dudbridge.tsv", sep="\t")
